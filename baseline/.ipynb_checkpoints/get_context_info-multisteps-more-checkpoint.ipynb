# %%
import os
GPU_id = 2
os.environ['CUDA_VISIBLE_DEVICES'] = str(GPU_id)

# %%
import pandas as pd
import cudf as gd
import numpy as np
import multiprocessing
import pickle
import matplotlib.pyplot as plt

from os import listdir
from os.path import isfile, join
from multiprocessing import Process
from librmm_cffi import librmm

# %%
def on_gpu(words,func,arg=None, dtype=np.int32):
    res = librmm.device_array(words.size(), dtype=dtype)
    if arg is None:
        cmd = 'words.%s(devptr=res.device_ctypes_pointer.value)'%(func)
    else:
        cmd = 'words.%s(arg,devptr=res.device_ctypes_pointer.value)'%(func)
    eval(cmd)
    return res

def on_gpu(words,func,arg=None, dtype=np.int32):
    res = librmm.device_array(words.size(), dtype=dtype)
    if arg is None:
        cmd = 'words.%s(devptr=res.device_ctypes_pointer.value)'%(func)
    else:
        cmd = 'words.%s(arg,devptr=res.device_ctypes_pointer.value)'%(func)
    eval(cmd)
    return res

# %%
"""
array(['search for poi', 'interaction item image', 'clickout item',
       'interaction item info', 'interaction item deals',
       'search for destination', 'filter selection',
       'interaction item rating', 'search for item',
       'change of sort order'], dtype=object)
"""


def get_future_or_past_info(data_click, data, thread_id, num_cores, name, num_steps_to_look=1):
    info = {}
    for i in range(data_click.shape[0]):
        if i % num_cores != thread_id:
            continue
        clickout_count = 0
        clickout_available = [False] * num_steps_to_look
        clickout_item = [0] * num_steps_to_look
        clickout_step_diff = [0] * num_steps_to_look
        clickout_timestamp_diff = [0] * num_steps_to_look
        clickout_price = [0] * num_steps_to_look
        clickout_is_same = [False] * num_steps_to_look

        clickout_impression_valid = [False] * num_steps_to_look
        clickout_price_mean = [0] * num_steps_to_look
        clickout_price_std = [0] * num_steps_to_look

        has_changed_sort = False
        sort_metric = "0"

        row_i = data_click.iloc[i]
        cur_item = row_i['reference']
        cur_item_interaction_image_count = 0
        cur_item_interaction_info_count = 0
        cur_item_interaction_deal_count = 0
        cur_item_interaction_rating_count = 0

        other_clicked_item_interaction_image_count = 0
        other_clicked_item_interaction_info_count = 0
        other_clicked_item_interaction_deal_count = 0
        other_clicked_item_interaction_rating_count = 0
        num_of_search_poi = 0

        all_row_id, user_id = row_i['all_row_id'], row_i['user_id']
        session_id, step = row_i['session_id'], row_i['step']
        if len(info) > 0 and len(info) % 3000 == 0:
            if thread_id == 0:
                print('thread 0 finished ', len(info))
        j_range = range(all_row_id + 1, data.shape[0]) if name == 'future' else range(all_row_id - 1, all_row_id - step,
                                                                                      -1)
        for j in j_range:
            row_j = data.iloc[j]
            if name == 'future' and (user_id != row_j['user_id'] or session_id != row_j['session_id']):
                break
            reference_j, action_j = row_j['reference'], row_j['action_type']

            if action_j == 'change of sort order' and not has_changed_sort:
                has_changed_sort = True
                sort_metric = reference_j
                continue
            if action_j == 'search for poi':
                num_of_search_poi += 1
                continue
            if not action_j.startswith('clickout') and not action_j.startswith('interaction'):
                continue
            try:
                if pd.notnull(reference_j):
                    if pd.notnull(cur_item):
                        if int(cur_item) == int(reference_j):
                            if action_j == 'interaction item image':
                                cur_item_interaction_image_count += 1
                            if action_j == 'interaction item info':
                                cur_item_interaction_info_count += 1
                            if action_j == 'interaction item deals':
                                cur_item_interaction_deal_count += 1
                            if action_j == 'interaction item rating':
                                cur_item_interaction_rating_count += 1
                        else:
                            clicked_item_list_int = [int(x) for x in clickout_item]
                            if int(reference_j) in clicked_item_list_int:
                                if action_j == 'interaction item image':
                                    other_clicked_item_interaction_image_count += 1
                                if action_j == 'interaction item info':
                                    other_clicked_item_interaction_info_count += 1
                                if action_j == 'interaction item deals':
                                    other_clicked_item_interaction_deal_count += 1
                                if action_j == 'interaction item rating':
                                    other_clicked_item_interaction_rating_count += 1
            except:
                pass
            if not action_j.startswith('clickout'):
                continue
            # only care about neighboring clickout
            if clickout_count < num_steps_to_look:
                clickout_available[clickout_count] = True
                clickout_item[clickout_count] = reference_j
                if pd.notnull(reference_j) and pd.notnull(cur_item):
                    clickout_is_same[clickout_count] = int(reference_j) == int(cur_item)
                clickout_step_diff[clickout_count] = row_j['step'] - step
                clickout_timestamp_diff[clickout_count] = row_j['timestamp'] - row_i['timestamp']
                if pd.isnull(row_j['impressions']):
                    continue
                impressions = row_j['impressions'].split("|")
                prices = row_j['prices'].split("|")
                clickout_impression_valid[clickout_count] = True
                clickout_price_mean[clickout_count] = np.mean(list(map(float, prices)))
                clickout_price_std[clickout_count] = np.std(list(map(float, prices)))
                if pd.notnull(reference_j):
                    reference_j = str(int(reference_j))
                    if reference_j in impressions:
                        clickout_price[clickout_count] = int(prices[impressions.index(reference_j)])
            clickout_count += 1
        info[i] = []
        for k in range(num_steps_to_look):
            info[i].extend([clickout_available[k], clickout_item[k], clickout_step_diff[k],
                       clickout_timestamp_diff[k], clickout_price[k], clickout_is_same[k],
                       clickout_impression_valid[k], clickout_price_mean[k], clickout_price_std[k]])
        info[i].extend([has_changed_sort, sort_metric, cur_item_interaction_image_count,
                        cur_item_interaction_info_count, cur_item_interaction_deal_count,
                        cur_item_interaction_rating_count, clickout_count, other_clicked_item_interaction_image_count,
                        other_clicked_item_interaction_info_count, other_clicked_item_interaction_deal_count,
                        other_clicked_item_interaction_rating_count, num_of_search_poi])
    df = pd.DataFrame.from_dict(info, orient='index')
    cols = ["clickout_available", "clickout_item", "clickout_step_diff",
            "clickout_timestamp_diff", "clickout_price", 'clickout_is_same',
            'clickout_impression_valid', 'clickout_price_mean', 'clickout_price_std']
    df_cols = []
    for k in range(num_steps_to_look):
        df_cols.extend(["{}_{}_{}".format(name, c, k) for c in cols])
    tmp = ["has_changed_sort", "sort_metric", "cur_item_interaction_image_count",
            "cur_item_interaction_info_count", "cur_item_interaction_deal_count",
            "cur_item_interaction_rating_count", "clickout_count", "other_clicked_item_interaction_image_count",
            "other_clicked_item_interaction_info_count",
            "other_clicked_item_interaction_deal_count",
            "other_clicked_item_interaction_rating_count",
            "num_of_search_poi"]
    df_cols.extend(["{}_{}".format(c, name) for c in tmp])
    df.columns = df_cols
    df['row_id'] = df.index
    df.to_pickle('cache/sub_{}_info_{}_multisteps.pkl'.format(name, thread_id))

# %%
# %%time
path = '/datasets/trivago/data'
train = gd.read_csv("{}/train.csv".format(path))
test = gd.read_csv("{}/test.csv".format(path))
train['is_train'] = 1
test['is_train'] = 0
data = gd.concat([train, test])
print('combined',data.shape)
# Out:
# combined (19715327, 13)
# CPU times: user 2.77 s, sys: 1.54 s, total: 4.3 s
# Wall time: 5.73 s

# %%
del train
del test

# %%
data['all_row_id'] = np.arange(data.shape[0])
data = data.to_pandas()

# %%
# %%time
data_click = pd.read_csv('cache/data_clickout.csv')
# Out:
# CPU times: user 7.76 s, sys: 1.01 s, total: 8.78 s
# Wall time: 8.8 s

# %%
data_click['row_id'] = data_click.index

# %%
data_click['reference'].replace('unknown', None, inplace=True)
data['reference'].replace('unknown', None, inplace=True)

# %%
data_click.shape
# Out:
# (2115365, 16)

# %%
data.head(100)
# Out:
#          user_id     session_id   timestamp  step             action_type  \
# 0   00RL8Z82B2Z1  aff3928535f48  1541037460     1          search for poi
# 1   00RL8Z82B2Z1  aff3928535f48  1541037522     2  interaction item image
# 2   00RL8Z82B2Z1  aff3928535f48  1541037522     3  interaction item image
# 3   00RL8Z82B2Z1  aff3928535f48  1541037532     4  interaction item image
# 4   00RL8Z82B2Z1  aff3928535f48  1541037532     5  interaction item image
# 5   00RL8Z82B2Z1  aff3928535f48  1541037532     6  interaction item image
# 6   00RL8Z82B2Z1  aff3928535f48  1541037532     7  interaction item image
# 7   00RL8Z82B2Z1  aff3928535f48  1541037532     8  interaction item image
# 8   00RL8Z82B2Z1  aff3928535f48  1541037542     9  interaction item image
# 9   00RL8Z82B2Z1  aff3928535f48  1541037542    10  interaction item image
# 10  00RL8Z82B2Z1  aff3928535f48  1541037542    11  interaction item image
# 11  00RL8Z82B2Z1  aff3928535f48  1541037542    12  interaction item image
# 12  00RL8Z82B2Z1  aff3928535f48  1541037542    13  interaction item image
# 13  00RL8Z82B2Z1  aff3928535f48  1541037543    14           clickout item
# 14  00RL8Z82B2Z1  aff3928535f48  1541038469    15          search for poi
# 15  00RL8Z82B2Z1  aff3928535f48  1541038485    16           clickout item
# 16  02HGRBA06ODU  fa3a53156ae5c  1541030832     1   interaction item info
# 17  02HGRBA06ODU  fa3a53156ae5c  1541030843     2  interaction item image
# 18  02HGRBA06ODU  fa3a53156ae5c  1541030843     3  interaction item image
# 19  02HGRBA06ODU  fa3a53156ae5c  1541030852     4   interaction item info
# 20  02HGRBA06ODU  fa3a53156ae5c  1541030867     5   interaction item info
# 21  02HGRBA06ODU  fa3a53156ae5c  1541030877     6  interaction item image
# 22  02HGRBA06ODU  fa3a53156ae5c  1541030877     7  interaction item image
# 23  02HGRBA06ODU  fa3a53156ae5c  1541030887     8  interaction item image
# 24  02HGRBA06ODU  fa3a53156ae5c  1541030887     9  interaction item image
# 25  02HGRBA06ODU  fa3a53156ae5c  1541030887    10  interaction item image
# 26  02HGRBA06ODU  fa3a53156ae5c  1541030897    11  interaction item image
# 27  02HGRBA06ODU  fa3a53156ae5c  1541030897    12  interaction item image
# 28  02HGRBA06ODU  fa3a53156ae5c  1541030897    13  interaction item image
# 29  02HGRBA06ODU  fa3a53156ae5c  1541030897    14  interaction item image
# ..           ...            ...         ...   ...                     ...
# 70  02HGRBA06ODU  fa3a53156ae5c  1541031088    55  interaction item image
# 71  02HGRBA06ODU  fa3a53156ae5c  1541031098    56  interaction item image
# 72  02HGRBA06ODU  fa3a53156ae5c  1541031098    57  interaction item image
# 73  02HGRBA06ODU  fa3a53156ae5c  1541031108    58  interaction item image
# 74  02HGRBA06ODU  fa3a53156ae5c  1541031108    59  interaction item image
# 75  02HGRBA06ODU  fa3a53156ae5c  1541031108    60  interaction item image
# 76  02HGRBA06ODU  fa3a53156ae5c  1541031108    61  interaction item image
# 77  02HGRBA06ODU  fa3a53156ae5c  1541031108    62  interaction item image
# 78  02HGRBA06ODU  fa3a53156ae5c  1541031108    63  interaction item image
# 79  02HGRBA06ODU  fa3a53156ae5c  1541031108    64  interaction item image
# 80  02HGRBA06ODU  fa3a53156ae5c  1541031115    65  interaction item image
# 81  02SRUT1NQYH1  3599a6f709eab  1541063730     1  interaction item image
# 82  02SRUT1NQYH1  3599a6f709eab  1541063730     2  interaction item image
# 83  02SRUT1NQYH1  3599a6f709eab  1541063740     3  interaction item image
# 84  02SRUT1NQYH1  3599a6f709eab  1541063740     4  interaction item image
# 85  02SRUT1NQYH1  3599a6f709eab  1541063740     5  interaction item image
# 86  02SRUT1NQYH1  3599a6f709eab  1541063750     6  interaction item image
# 87  02SRUT1NQYH1  3599a6f709eab  1541063760     7  interaction item image
# 88  02SRUT1NQYH1  3599a6f709eab  1541063760     8  interaction item image
# 89  02SRUT1NQYH1  3599a6f709eab  1541063760     9  interaction item image
# 90  02SRUT1NQYH1  3599a6f709eab  1541063770    10  interaction item image
# 91  02SRUT1NQYH1  3599a6f709eab  1541063770    11  interaction item image
# 92  02SRUT1NQYH1  3599a6f709eab  1541063770    12  interaction item image
# 93  02SRUT1NQYH1  3599a6f709eab  1541063770    13  interaction item image
# 94  02SRUT1NQYH1  3599a6f709eab  1541063770    14  interaction item image
# 95  02SRUT1NQYH1  3599a6f709eab  1541063770    15  interaction item image
# 96  02SRUT1NQYH1  3599a6f709eab  1541063770    16  interaction item image
# 97  02SRUT1NQYH1  3599a6f709eab  1541063780    17  interaction item image
# 98  02SRUT1NQYH1  3599a6f709eab  1541063780    18  interaction item image
# 99  02SRUT1NQYH1  3599a6f709eab  1541063790    19  interaction item image
#
#       reference platform               city  device current_filters  \
# 0       Newtown       AU  Sydney, Australia  mobile            None
# 1        666856       AU  Sydney, Australia  mobile            None
# 2        666856       AU  Sydney, Australia  mobile            None
# 3        666856       AU  Sydney, Australia  mobile            None
# 4        109038       AU  Sydney, Australia  mobile            None
# 5        666856       AU  Sydney, Australia  mobile            None
# 6        109038       AU  Sydney, Australia  mobile            None
# 7        666856       AU  Sydney, Australia  mobile            None
# 8        109038       AU  Sydney, Australia  mobile            None
# 9        109038       AU  Sydney, Australia  mobile            None
# 10       109038       AU  Sydney, Australia  mobile            None
# 11       109038       AU  Sydney, Australia  mobile            None
# 12       109038       AU  Sydney, Australia  mobile            None
# 13       109038       AU  Sydney, Australia  mobile            None
# 14  Surry Hills       AU  Sydney, Australia  mobile            None
# 15      1257342       AU  Sydney, Australia  mobile            None
# 16      3377332       BR    Ubatuba, Brazil  mobile            None
# 17      3377332       BR    Ubatuba, Brazil  mobile            None
# 18      3377332       BR    Ubatuba, Brazil  mobile            None
# 19      3377332       BR    Ubatuba, Brazil  mobile            None
# 20      3066244       BR    Ubatuba, Brazil  mobile            None
# 21      3066244       BR    Ubatuba, Brazil  mobile            None
# 22      3066244       BR    Ubatuba, Brazil  mobile            None
# 23      3066244       BR    Ubatuba, Brazil  mobile            None
# 24      3066244       BR    Ubatuba, Brazil  mobile            None
# 25      3066244       BR    Ubatuba, Brazil  mobile            None
# 26      3066244       BR    Ubatuba, Brazil  mobile            None
# 27      3066244       BR    Ubatuba, Brazil  mobile            None
# 28      3066244       BR    Ubatuba, Brazil  mobile            None
# 29      3066244       BR    Ubatuba, Brazil  mobile            None
# ..          ...      ...                ...     ...             ...
# 70      3066244       BR    Ubatuba, Brazil  mobile            None
# 71      3066244       BR    Ubatuba, Brazil  mobile            None
# 72      3066244       BR    Ubatuba, Brazil  mobile            None
# 73      3066244       BR    Ubatuba, Brazil  mobile            None
# 74      3066244       BR    Ubatuba, Brazil  mobile            None
# 75      3066244       BR    Ubatuba, Brazil  mobile            None
# 76      3066244       BR    Ubatuba, Brazil  mobile            None
# 77      3066244       BR    Ubatuba, Brazil  mobile            None
# 78      3066244       BR    Ubatuba, Brazil  mobile            None
# 79      3066244       BR    Ubatuba, Brazil  mobile            None
# 80      3066244       BR    Ubatuba, Brazil  mobile            None
# 81      2795374       FI     Krakow, Poland  mobile            None
# 82      2795374       FI     Krakow, Poland  mobile            None
# 83      2795374       FI     Krakow, Poland  mobile            None
# 84      2795374       FI     Krakow, Poland  mobile            None
# 85      2795374       FI     Krakow, Poland  mobile            None
# 86      2795374       FI     Krakow, Poland  mobile            None
# 87      2795374       FI     Krakow, Poland  mobile            None
# 88      2795374       FI     Krakow, Poland  mobile            None
# 89      2795374       FI     Krakow, Poland  mobile            None
# 90      2795374       FI     Krakow, Poland  mobile            None
# 91      2795374       FI     Krakow, Poland  mobile            None
# 92      2795374       FI     Krakow, Poland  mobile            None
# 93      2795374       FI     Krakow, Poland  mobile            None
# 94      2795374       FI     Krakow, Poland  mobile            None
# 95      2795374       FI     Krakow, Poland  mobile            None
# 96      2795374       FI     Krakow, Poland  mobile            None
# 97      2795374       FI     Krakow, Poland  mobile            None
# 98      2795374       FI     Krakow, Poland  mobile            None
# 99      2795374       FI     Krakow, Poland  mobile            None
#
#                                           impressions  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  3400638|1253714|3367857|5100540|1088584|666916...
# 14                                               None
# 15  55109|129343|54824|2297972|109014|1257342|1031...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# ..                                                ...
# 70                                               None
# 71                                               None
# 72                                               None
# 73                                               None
# 74                                               None
# 75                                               None
# 76                                               None
# 77                                               None
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
# 83                                               None
# 84                                               None
# 85                                               None
# 86                                               None
# 87                                               None
# 88                                               None
# 89                                               None
# 90                                               None
# 91                                               None
# 92                                               None
# 93                                               None
# 94                                               None
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                                prices  is_train  all_row_id
# 0                                                None         1           0
# 1                                                None         1           1
# 2                                                None         1           2
# 3                                                None         1           3
# 4                                                None         1           4
# 5                                                None         1           5
# 6                                                None         1           6
# 7                                                None         1           7
# 8                                                None         1           8
# 9                                                None         1           9
# 10                                               None         1          10
# 11                                               None         1          11
# 12                                               None         1          12
# 13  95|66|501|112|95|100|101|72|82|56|56|143|70|25...         1          13
# 14                                               None         1          14
# 15  162|25|150|143|101|49|118|131|18|100|101|143|5...         1          15
# 16                                               None         1          16
# 17                                               None         1          17
# 18                                               None         1          18
# 19                                               None         1          19
# 20                                               None         1          20
# 21                                               None         1          21
# 22                                               None         1          22
# 23                                               None         1          23
# 24                                               None         1          24
# 25                                               None         1          25
# 26                                               None         1          26
# 27                                               None         1          27
# 28                                               None         1          28
# 29                                               None         1          29
# ..                                                ...       ...         ...
# 70                                               None         1          70
# 71                                               None         1          71
# 72                                               None         1          72
# 73                                               None         1          73
# 74                                               None         1          74
# 75                                               None         1          75
# 76                                               None         1          76
# 77                                               None         1          77
# 78                                               None         1          78
# 79                                               None         1          79
# 80                                               None         1          80
# 81                                               None         1          81
# 82                                               None         1          82
# 83                                               None         1          83
# 84                                               None         1          84
# 85                                               None         1          85
# 86                                               None         1          86
# 87                                               None         1          87
# 88                                               None         1          88
# 89                                               None         1          89
# 90                                               None         1          90
# 91                                               None         1          91
# 92                                               None         1          92
# 93                                               None         1          93
# 94                                               None         1          94
# 95                                               None         1          95
# 96                                               None         1          96
# 97                                               None         1          97
# 98                                               None         1          98
# 99                                               None         1          99
#
# [100 rows x 14 columns]

# %%
num_cores = 50
path = 'cache'
for name in ['past', 'future']:
    proc_list = []
    for thread_id in range(num_cores):
        p = Process(target=get_future_or_past_info, 
                    args=(data_click, data, thread_id, num_cores, name, 2))
        proc_list.append(p)
    for p in proc_list:
        p.start()
    for p in proc_list:
        p.join()
    files = [f for f in listdir(path) if isfile(join(path, f)) and f.startswith('sub_{}'.format(name))]
    df_list = []
    for f in files:
        df = pd.read_pickle(join(path, f))
        df_list.append(df)

    df = pd.concat(df_list)
    df = df.sort_values(by=['row_id'])
    print('shape match: ', df.shape[0] == data_click.shape[0])
    df.to_csv('cache/{}_info.csv'.format(name), index=False)
# Out:
# thread 0 finished  3000
# thread 0 finished  6000
# thread 0 finished  9000
# thread 0 finished  12000
# thread 0 finished  15000
# thread 0 finished  18000
# thread 0 finished  21000
# thread 0 finished  24000
# thread 0 finished  27000
# thread 0 finished  30000
# thread 0 finished  33000
# thread 0 finished  36000
# thread 0 finished  39000
# thread 0 finished  42000
# shape match:  True
# thread 0 finished  3000
# thread 0 finished  6000
# thread 0 finished  9000
# thread 0 finished  12000
# thread 0 finished  15000
# thread 0 finished  18000
# thread 0 finished  21000
# thread 0 finished  24000
# thread 0 finished  27000
# thread 0 finished  30000
# thread 0 finished  33000
# thread 0 finished  36000
# thread 0 finished  39000
# thread 0 finished  42000
# shape match:  True

# %%
! rm cache/sub*

# %%
past_info = pd.read_csv('cache/past_info.csv')
future_info = pd.read_csv('cache/future_info.csv')
# Out:
# /conda/envs/rapids/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
future_info.shape
# Out:
# (2115365, 31)

# %%
data_context = past_info.merge(future_info, on='row_id', how='left')
data_context.to_csv('cache/context_info_multi_2_more.csv'.format(name), index=False)

# %%
data_context.shape
# Out:
# (2115365, 61)

# %%
data_context.columns
# Out:
# Index(['past_clickout_available_0', 'past_clickout_item_0',
#        'past_clickout_step_diff_0', 'past_clickout_timestamp_diff_0',
#        'past_clickout_price_0', 'past_clickout_is_same_0',
#        'past_clickout_impression_valid_0', 'past_clickout_price_mean_0',
#        'past_clickout_price_std_0', 'past_clickout_available_1',
#        'past_clickout_item_1', 'past_clickout_step_diff_1',
#        'past_clickout_timestamp_diff_1', 'past_clickout_price_1',
#        'past_clickout_is_same_1', 'past_clickout_impression_valid_1',
#        'past_clickout_price_mean_1', 'past_clickout_price_std_1',
#        'has_changed_sort_past', 'sort_metric_past',
#        'cur_item_interaction_image_count_past',
#        'cur_item_interaction_info_count_past',
#        'cur_item_interaction_deal_count_past',
#        'cur_item_interaction_rating_count_past', 'clickout_count_past',
#        'other_clicked_item_interaction_image_count_past',
#        'other_clicked_item_interaction_info_count_past',
#        'other_clicked_item_interaction_deal_count_past',
#        'other_clicked_item_interaction_rating_count_past',
#        'num_of_search_poi_past', 'row_id', 'future_clickout_available_0',
#        'future_clickout_item_0', 'future_clickout_step_diff_0',
#        'future_clickout_timestamp_diff_0', 'future_clickout_price_0',
#        'future_clickout_is_same_0', 'future_clickout_impression_valid_0',
#        'future_clickout_price_mean_0', 'future_clickout_price_std_0',
#        'future_clickout_available_1', 'future_clickout_item_1',
#        'future_clickout_step_diff_1', 'future_clickout_timestamp_diff_1',
#        'future_clickout_price_1', 'future_clickout_is_same_1',
#        'future_clickout_impression_valid_1', 'future_clickout_price_mean_1',
#        'future_clickout_price_std_1', 'has_changed_sort_future',
#        'sort_metric_future', 'cur_item_interaction_image_count_future',
#        'cur_item_interaction_info_count_future',
#        'cur_item_interaction_deal_count_future',
#        'cur_item_interaction_rating_count_future', 'clickout_count_future',
#        'other_clicked_item_interaction_image_count_future',
#        'other_clicked_item_interaction_info_count_future',
#        'other_clicked_item_interaction_deal_count_future',
#        'other_clicked_item_interaction_rating_count_future',
#        'num_of_search_poi_future'],
#       dtype='object')
